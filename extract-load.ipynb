# %%
from dotenv import load_dotenv
import os
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# Load the environment variables
load_dotenv()

uri = f"mongodb+srv://ledsouza:{os.getenv('MONGODB_PASSWORD')}@cluster-mais1cafe.editxaq.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
import streamlit as st
from streamlit_gsheets import GSheetsConnection
import pandas as pd

conn = st.connection("gsheets", type=GSheetsConnection)

metas = conn.read(usecols=range(8), ttl="0", worksheet="Metas")
metas.dropna(inplace=True)
metas["Data"] = pd.to_datetime(metas["Data"], format="%m/%d/%Y")
metas.sort_values(by="Data", ascending=False, inplace=True)

metas.head()
# Out:
# 2024-02-17 17:27:08.556
# ...
#   command:
#
#     streamlit run /Users/leandrosouza/Documents/Python Projects/Dashboard_mais1cafe/.venv/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-02-17 17:27:08.559 No runtime found, using MemoryCacheStorageManager
# 2024-02-17 17:27:08.560 No runtime found, using MemoryCacheStorageManager
#         Data  Clientes  Produtos   PA  Ticket Médio  Faturamento  \
# 0 2024-01-31      1.17      0.78  2.0          0.83         0.92
# 1 2024-01-30      1.12      0.66  1.7          0.86         0.96
# 2 2024-01-29      1.07      0.77  2.1          1.11         1.20
# 3 2024-01-27      0.80      0.61  2.3          1.21         0.97
# 4 2024-01-26      1.00      0.53  1.6          0.76         0.76
#
#    Cliente/Hora       Clima
# 0           4.2  Ensolarado
# 1           4.0  Ensolarado
# 2           3.9  Ensolarado
# 3           2.9     Nublado
# 4           3.6     Chuvoso

# %%
db = client["db_mais1cafe"]
collection = db["metas"]

# %%
metas.to_dict('records')
# Out:
# [{'Data': Timestamp('2024-01-31 00:00:00'),
#   'Clientes': 1.17,
#   'Produtos': 0.78,
#   'PA': 2.0,
#   'Ticket Médio': 0.83,
#   'Faturamento': 0.92,
#   'Cliente/Hora': 4.2,
#   'Clima': 'Ensolarado'},
#  {'Data': Timestamp('2024-01-30 00:00:00'),
#   'Clientes': 1.12,
#   'Produtos': 0.66,
#   'PA': 1.7,
#   'Ticket Médio': 0.86,
#   'Faturamento': 0.96,
#   'Cliente/Hora': 4.0,
#   'Clima': 'Ensolarado'},
#  {'Data': Timestamp('2024-01-29 00:00:00'),
#   'Clientes': 1.07,
#   'Produtos': 0.77,
#   'PA': 2.1,
#   'Ticket Médio': 1.11,
#   'Faturamento': 1.2,
#   'Cliente/Hora': 3.9,
#   'Clima': 'Ensolarado'},
#  {'Data': Timestamp('2024-01-27 00:00:00'),
#   'Clientes': 0.8,
#   'Produtos': 0.61,
#   'PA': 2.3,
#   'Ticket Médio': 1.21,
#   'Faturamento': 0.97,
#   'Cliente/Hora': 2.9,
#   'Clima': 'Nublado'},
#  {'Data': Timestamp('2024-01-26 00:00:00'),
#   'Clientes': 1.0,
#   'Produtos': 0.53,
#   'PA': 1.6,
#   'Ticket Médio': 0.76,
#   'Faturamento': 0.76,
# ...

# %%
collection.insert_many(metas.to_dict('records'))
# Out:
# InsertManyResult([ObjectId('65d11874a8a506d3a39196bf'), ObjectId('65d11874a8a506d3a39196c0'), ObjectId('65d11874a8a506d3a39196c1'), ObjectId('65d11874a8a506d3a39196c2'), ObjectId('65d11874a8a506d3a39196c3'), ObjectId('65d11874a8a506d3a39196c4'), ObjectId('65d11874a8a506d3a39196c5'), ObjectId('65d11874a8a506d3a39196c6'), ObjectId('65d11874a8a506d3a39196c7'), ObjectId('65d11874a8a506d3a39196c8'), ObjectId('65d11874a8a506d3a39196c9'), ObjectId('65d11874a8a506d3a39196ca'), ObjectId('65d11874a8a506d3a39196cb'), ObjectId('65d11874a8a506d3a39196cc'), ObjectId('65d11874a8a506d3a39196cd'), ObjectId('65d11874a8a506d3a39196ce'), ObjectId('65d11874a8a506d3a39196cf'), ObjectId('65d11874a8a506d3a39196d0'), ObjectId('65d11874a8a506d3a39196d1'), ObjectId('65d11874a8a506d3a39196d2'), ObjectId('65d11874a8a506d3a39196d3'), ObjectId('65d11874a8a506d3a39196d4'), ObjectId('65d11874a8a506d3a39196d5'), ObjectId('65d11874a8a506d3a39196d6'), ObjectId('65d11874a8a506d3a39196d7'), ObjectId('65d11874a8a506d3a391
# ...
